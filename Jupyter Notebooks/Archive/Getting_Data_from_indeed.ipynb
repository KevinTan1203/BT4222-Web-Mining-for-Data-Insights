# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# # Getting Job Posting from Indeed
# - https://www.indeed.com.sg/
# - https://www.indeed.com.sg/jobs?q=data+scientist&l=
# - https://www.indeed.com.sg/jobs?q=data+scientist&l=Central+Business+District
#
# URL strucutre can be inferred as we check the series of pages from our interest website.
# Our challenge now is to make sure we understand the logic of the URL as the pages we want to scrape change. If we can’t understand this logic enough so we can implement it into code, then we'll reach a dead end.

# %% [markdown]
# # Reading a URL using `urllib`
#
# More info: https://docs.python.org/3/howto/urllib2.html

# %%
import urllib.request
url = "https://www.indeed.com.sg/jobs?q=data%20scientist&l=Central%20Business%20District"
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)

html = response.read().decode('unicode_escape')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: invalid escape sequence '\/'

# %%
# !python --version
# Out:
# Python 3.6.7

# %%
import bs4
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
# print(soup.prettify())

# %%
print(soup.get_text())
# Out:
#
#     if (typeof window['closureReadyCallbacks'] == 'undefined') {
#         window['closureReadyCallbacks'] = [];
#     }
#
#     function call_when_jsall_loaded(cb) {
#         if (window['closureReady']) {
#             cb();
#         } else {
#             window['closureReadyCallbacks'].push(cb);
#         }
#     }
#
#
#
#
#
# var searchUID = '1cue6vq2sbs11800';
# var tk = '1cue6vq2sbs11800';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;8232301';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/www.indeed.com.sg\/account\/login?dest=%2Fjobs%3Fq%3Ddata%2520scientist%26l%3DCentral%2520Business%2520District';
# var globalRegisterURL = 'https:\/\/www.indeed.com.sg\/account\/register?dest=%2Fjobs%3Fq%3Ddata%2520scientist%26l%3DCentral%2520Business%2520District';
# var searchKey = '8de656acbbcecf09';
# var searchState = 'q=data+scientist&amp;l=Central+Business+District';
# ...

# %% [markdown]
# ### extract job title
# - Each job posting is nested under $\lt$div$\gt$ tags, wtih an attribute "class"="jobsearch-SerpJobCard row result"
# - Then, job titles are listed under $\lt$a$\gt$ tags, with atrribute "title"
#
# Therefore, to extract job title:
# 1. detect all $\lt$div$\gt$ tags with class containing "row"
# 2. then, find $\lt$a$\gt$ tags with attribute "data-tn-element":"jobTitle"
# 3. for all of these $\lt$a$\gt$ tags, extract the value of attribute "title"

# %%
def extract_job_title_from_result(soup): 
    jobs = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
            jobs.append(a["title"])
    return(jobs)
jobnames = extract_job_title_from_result(soup)

# %%
jobnames
# Out:
# ['Data Scientist (Text Analytics)',
#  'Data Scientist - Remote OK',
#  'Junior Data Scientist (CLT)',
#  'Data Scientist',
#  'Tech U - Associate Data Scientist',
#  'Data Scientist',
#  'Junior Data Scientist',
#  'Machine Learning Scientist',
#  'Data Scientist',
#  'Data Scientist (Economics/Machine Learning)']

# %% [markdown]
# ### extract company name
# - Each job posting is nested under $\lt$div$\gt$ tags, wtih an attribute "class"="jobsearch-SerpJobCard row result"
# - Then, company are listed under $\lt$span$\gt$ tags, with atrribute "class=company"
#
# Therefore, to extract job title:
# 1. detect all $\lt$div$\gt$ tags with class containing "row"
# 2. then, find $\lt$span$\gt$ tags with attribute "class":"company"
# 3. for all of these $\lt$span$\gt$ tags, extract the value

# %%
def extract_company_from_result(soup): 
    companies = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        company = div.find_all(name="span", attrs={"class":"company"})       
        for b in company:
            companies.append(b.text.strip())
    return(companies)
 
companynames = extract_company_from_result(soup)

# %%
import pandas as pd
job_info = pd.DataFrame({'jobtitle':jobnames, 'companyname': companynames})

# %%
job_info.head()
# Out:
#   companyname                    jobtitle
# 0      DANONE       Data Scientist Intern
# 1   DataRobot              Data Scientist
# 2  INDORSE.IO  Data Scientist - Remote OK
# 3    CLARIANT              Data Scientist
# 4    IntroPro              Data Scientist
