# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 4.2 MB/s
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.19.6

# %%
import glob
import re
import os
import fitz
import numpy as np
import pandas as pd
import math
import json
import pprint

import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
import spacy

import gensim.corpora as corpora
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import collections
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
# --------------------------- Read a pdf into a large string of text ---------------------------
def read_pdf(file_path):
    pymupdf_text = ""
    with fitz.open(file_path) as doc:
        for page in doc:
            pymupdf_text += page.getText()
    return pymupdf_text


# --------------------------- Read a report and breaks it up into individual sentences ---------------------------
def convert_pdf_into_sentences(text):
    # Remove unnecessary spaces and line breaks
    text = re.sub(r'\x0c\x0c|\x0c', "", str(text))
    text = re.sub('\n ', '', str(text))
    text = re.sub('\n', ' ', str(text))
    text = ' '.join(text.split())
    text = " " + text + "  "
    text = text.replace("\n", " ")
    if "”" in text: text = text.replace(".”", "”.")
    if "\"" in text: text = text.replace(".\"", "\".")
    if "!" in text: text = text.replace("!\"", "\"!")
    if "?" in text: text = text.replace("?\"", "\"?")
    text = text.replace(".", ".<stop>")
    text = text.replace("?", "?<stop>")
    text = text.replace("!", "!<stop>")
    text = text.replace("<prd>", ".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]

    # Filter for sentences with more than 100 characters
    sentences = [s.strip() for s in sentences if len(s) > 100]
    return sentences


# --------------------------- Retrieve the report name from the pdf ---------------------------
def reportName(path):
    name = path.split('/')[-1]
    company = name.split('.')[0]
    return company

# %%
# Read our database of ESG reports
path = 'Reports 2.0'
esg_reports = glob.glob(path + '/*.pdf')
esg_corpus = {}
for report in esg_reports:
    esg_corpus[reportName(report)] = convert_pdf_into_sentences(read_pdf(report))
    print(f"Reading Report '{reportName(report)}'")
# Out:
# Deprecation: 'getText' removed from class 'Page' after v1.19 - use 'get_text'.
# Reading Report 'Enea'
# Reading Report 'TIS, Inc'
# Reading Report 'Sopra Steria Group'
# Reading Report 'Rackspace Technology Global, Inc'
# Reading Report 'Infomedia Ltd'
# Reading Report 'IGG Inc'
# Reading Report 'Datamatics Global Services Ltd'
# Reading Report 'Intuit Inc'
# Reading Report 'Data Respons'
# Reading Report 'POSCO ICT Co Ltd'
# Reading Report 'ShotSpotter, Inc'
# Reading Report 'Kape Technologies'
# Reading Report 'Parsons Corp'
# Reading Report 'Crayon Group Holding'
# Reading Report 'Grace Technology, Inc'
# Reading Report 'G5 Entertainment'
# Reading Report 'Happiest Minds Technologies Ltd'
# Reading Report 'iFAST Corp Ltd'
# Reading Report 'Ceridian HCM Holding, Inc'
# Reading Report 'Booking Holdings Inc'
# Reading Report 'Nintendo Co Ltd'
# Reading Report 'Nihon Unisys, Ltd'
# Reading Report 'Autodesk Inc'
# Reading Report 'Sykes Enterprises, Inc'
# Reading Report 'Naspers Ltd'
# Reading Report 'Linx'
# Reading Report 'Accenture'
# Reading Report 'Linedata Services'
# Reading Report 'Lime Technologies'
# Reading Report 'Adobe, Inc'
# Reading Report 'The Western Union Co'
# Reading Report 'TradeDoubler'
# Reading Report 'Techedge'
# Reading Report 'BlackBerry Ltd'
# Reading Report 'Nuance Communications, Inc'
# Reading Report 'Cyient Ltd'
# Reading Report 'GB Group'
# Reading Report 'ManTech International Corp'
# Reading Report 'Sabre Corp'
# Reading Report 'Information Services International-Dentsu, Ltd'
# Reading Report 'BrainChip Holdings Ltd'
# Reading Report 'Rovio Entertainment Oyj'
# Reading Report 'Computershare'
# Reading Report 'Blackbaud, Inc'
# Reading Report 'FLEETCOR Technologies, Inc'
# Reading Report 'Mitsubishi Research Institute, Inc'
# Reading Report 'Joy Spreader Group, Inc'
# Reading Report 'Money Forward, Inc'
# Reading Report 'Just Dial Ltd'
# Reading Report 'Matrix IT Ltd'
# Reading Report 'Sea Ltd'
# Reading Report 'Alpha Systems Inc'
# Reading Report 'Cass Information Systems, Inc'
# Reading Report 'Fidelity National Information Services Inc'
# Reading Report 'Redbubble Ltd'
# Reading Report 'Carsales'
# Reading Report 'Aspire Global'
# Reading Report 'Net One Systems Co Ltd'
# Reading Report 'Evertec Inc'
# Reading Report 'TietoEVRY Corp'
# Reading Report 'HubSpot Inc'
# Reading Report 'Tenable Holdings, Inc'
# Reading Report 'Mensch und Maschine Software'
# Reading Report 'Paycom Software Inc'
# Reading Report 'Jack Henry & Associates Inc'
# Reading Report 'DXC Technology'
# Reading Report 'Technology One Ltd'
# Reading Report 'CMGE Technology Group Ltd'
# Reading Report 'BTRS Holdings, Inc'
# Reading Report 'Microsoft Corp'
# Reading Report 'Mastek Ltd'
# Reading Report 'Proact IT Group'
# Reading Report 'SS&C Technologies Holdings, Inc'
# Reading Report 'Lyft, Inc'
# Reading Report 'Tech Mahindra Ltd'
# Reading Report 'Alight, Inc'
# Reading Report 'GoDaddy Inc'
# Reading Report 'BlackLine, Inc'
# Reading Report 'Scicom (MSC) Bhd'
# Reading Report 'SAP'
# Reading Report 'Hi Sun Technology (China) Ltd'
# Reading Report 'Atea'
# Reading Report 'SCSK Corp'
# Reading Report 'Sesa SpA'
# Reading Report 'Cision Ltd'
# Reading Report 'Indra Sistemas'
# Reading Report 'Science Applications International Corp'
# Reading Report 'Esker'
# Reading Report 'FD Technologies'
# Reading Report 'CSAM Health Group'
# Reading Report 'NTT DATA Corp'
# Reading Report 'Keywords Studios'
# Reading Report 'F-Secure'
# Reading Report 'Integrated Research Ltd'
# Reading Report 'Leidos Holdings Inc'
# Reading Report 'SDL'
# Reading Report 'Black Knight, Inc'
# Reading Report 'Nepa'
# Reading Report 'BIMobject'
# Reading Report 'Atos'
# Reading Report 'HCL Technologies Ltd'
# Reading Report 'Q2 Holdings, Inc'
# Reading Report 'Sword Group'
# Reading Report 'NICE Ltd (Israel)'
# Reading Report 'PayPal Holdings Inc'
# Reading Report 'Audinate Group Ltd'
# Reading Report 'Mercadolibre, Inc'
# Reading Report 'Bytes Technology Group'
# Reading Report 'New Work'
# Reading Report 'CommVault Systems'
# Reading Report 'PROS Holdings, Inc'
# Reading Report 'msg life ag'
# Reading Report 'Kanematsu Electronics Ltd'
# Reading Report 'Kinaxis Inc'
# Reading Report 'Birlasoft Ltd'
# Reading Report 'Globant'
# Reading Report 'SimCorp'
# Reading Report 'Bilibili, Inc'
# Reading Report 'Readly International'
# Reading Report 'Cielo'
# Reading Report 'Quotient Technology Inc'
# Reading Report 'Razer, Inc'
# Reading Report 'Datagroup'
# Reading Report 'Ideanomics, Inc'
# Reading Report 'Sumo Logic, Inc'
# Reading Report 'Etsy Inc'
# Reading Report 'AVEVA Group'
# Reading Report 'SII'
# Reading Report 'Hinduja Global Solutions Ltd'
# Reading Report 'NCsoft Corp'
# Reading Report 'Better Collective'
# Reading Report 'Match Group, Inc'
# Reading Report 'Dropbox, Inc'
# Reading Report 'Nemetschek'
# Reading Report 'Mango Excellent Media Co Ltd'
# Reading Report 'Tencent Holdings Ltd'
# Reading Report 'Adyen'
# Reading Report 'Rightmove'
# Reading Report 'L&T Technology Services Ltd'
# Reading Report 'NetScout Systems, Inc'
# Reading Report 'Bravura Solutions Ltd'
# Reading Report 'Mphasis Ltd'
# Reading Report 'Devoteam'
# Reading Report 'GFT Technologies'
# Reading Report 'Bouvet'
# Reading Report 'Ideagen'
# Reading Report 'Digimarc Corp'
# Reading Report 'TeamViewer'
# Reading Report 'Total System Services'
# Reading Report 'cBrain'
# Reading Report 'Computacenter'
# Reading Report 'Kahoot!'
# Reading Report 'Mimecast Ltd'
# Reading Report 'ExlService Holdings, Inc'
# Reading Report 'Embracer Group'
# Reading Report 'mixi Inc'
# Reading Report 'Iflytek Co Ltd'
# Reading Report 'Softronic'
# Reading Report 'DKV MOBILITY SERVICES HOLDING'
# Reading Report 'Flexential Corp'
# Reading Report 'Link Administration Holdings Ltd'
# Reading Report 'Qualys Inc'
# Reading Report 'Itera'
# Reading Report 'Blue Prism Group PLC'
# Reading Report 'NetEnt'
# Reading Report 'Penneo'
# Reading Report 'Electronic Arts Inc'
# Reading Report 'SoftwareONE Holding'
# Reading Report 'Chatwork Co'
# Reading Report 'Rakus Co Ltd'
# Reading Report 'Prosus NV'
# Reading Report 'Remedy Entertainment'
# Reading Report 'F5, Inc'
# Reading Report 'Fiserv Inc'
# Reading Report 'International Business Machines Corp'
# Reading Report 'Leo Group Co Ltd'
# Reading Report 'Kakao Games Corp'
# Reading Report 'Optim Corp'
# Reading Report 'Just Eat Takeaway'
# Reading Report 'Endava'
# Reading Report 'Polygon'
# Reading Report 'Ordina NV'
# Reading Report 'FDM Group Holdings'
# Reading Report 'Palo Alto Networks Inc'
# Reading Report 'Synopsys, Inc'
# Reading Report 'SMS Co Ltd'
# Reading Report 'MyEG Services Bhd'
# Reading Report 'Cognizant Technology Solutions Corp'
# Reading Report 'Cloudflare, Inc'
# Reading Report 'Avast'
# Reading Report 'ITOCHU Techno-Solutions Corp'
# Reading Report 'Imdex Ltd'
# Reading Report 'Softcat'
# Reading Report 'Persistent Systems Ltd'
# Reading Report 'IRESS Ltd'
# Reading Report 'Delivery Hero'
# Reading Report 'FriendTimes, Inc'
# Reading Report 'Gofore'
# Reading Report 'NetEase, Inc'
# Reading Report 'Citrix Systems Inc'
# Reading Report 'Genpact Ltd'
# Reading Report 'Equiniti Group'
# Reading Report 'Totvs'
# Reading Report 'GMO Payment Gateway Inc'
# Reading Report 'IAC Interactive Corp'
# Reading Report 'Econocom Group'
# Reading Report 'Learning Technologies Group'
# Reading Report 'Esi Group'
# Reading Report 'Kingdee International Software Group Co Ltd'
# Reading Report 'Renalytix'
# Reading Report 'Starbreeze'
# Reading Report 'Logicom Public Ltd'
# Reading Report 'Network International Holdings'
# Reading Report 'Iomart Group'
# Reading Report 'Catena Media'
# Reading Report 'Silverlake Axis Ltd'
# Reading Report 'Take-Two Interactive Software, Inc'
# Reading Report 'ACI Worldwide, Inc'
# Reading Report 'Maoyan Entertainment'
# Reading Report 'Rakuten Group, Inc'
# Reading Report 'Forrester Research, Inc'
# Reading Report 'CoreLogic Inc'
# Reading Report 'NAVER Corp'
# Reading Report 'Izertis'
# Reading Report 'Bmit Technologies'
# Reading Report 'Nagarro'
# Reading Report 'Dassault Systems'
# Reading Report 'Modern Times Group MTG'
# Reading Report 'Kainos Group'
# Reading Report 'CWT International Ltd'
# Reading Report 'EHang Holdings Ltd'
# Reading Report 'Frontier Developments'
# Reading Report 'Reply SPA'
# Reading Report 'Absolute Software Corp'
# Reading Report 'Bittium Oyj'
# Reading Report 'ServiceNow Inc'
# Reading Report 'KPIT Technologies Ltd'
# Reading Report 'PSI Software AG'
# Reading Report 'China TransInfo Technology Co'
# Reading Report 'IndiaMART InterMESH Ltd'
# Reading Report 'Netcompany Group'
# Reading Report 'Digia'
# Reading Report 'Data#3 Ltd'
# Reading Report 'Mercari, Inc'
# Reading Report 'OTSUKA CORP'
# Reading Report 'Inke Ltd'
# Reading Report 'Media & Games Invest'
# Reading Report 'Costar Group, Inc'
# Reading Report 'HengTen Networks Group Ltd'
# Reading Report 'Global Dominion Access'
# Reading Report 'Akamai Technologies Inc'
# Reading Report 'adesso'
# Reading Report 'Sunevision Holdings Ltd'
# Reading Report 'Tata Consultancy Services Ltd'
# Reading Report 'Gaming Innovation Group Inc'
# Reading Report 'Fair Isaac Corp'
# Reading Report 'Exasol'
# Reading Report 'Sansan, Inc'
# Reading Report 'Nuix Ltd'
# Reading Report 'DTS Corp'
# Reading Report 'IAR Systems Group'
# Reading Report 'CyberArk Software Ltd'
# Reading Report 'ICT Group'
# Reading Report 'home24'
# Reading Report 'Origo hf'
# Reading Report 'Kuaishou Technology'
# Reading Report 'Liquidity Services, Inc'
# Reading Report 'Thunder Software Technology Co Ltd'
# Reading Report 'Global Payments Inc'
# Reading Report 'Edenred'
# Reading Report 'Open Text Corp'
# Reading Report 'Micro Focus International'
# Reading Report '2U, Inc'
# Reading Report 'Kingsoft Corp Ltd'
# Reading Report 'Mercell Holding'
# Reading Report 'Roper Technologies Inc'
# Reading Report 'Procore Technologies, Inc'
# Reading Report 'Coupa Software, Inc'
# Reading Report 'Oracle Corp'
# Reading Report 'Fabasoft'
# Reading Report 'Medallia, Inc'
# Reading Report 'Atlassian Corp'
# Reading Report 'Alibaba Group Holding Ltd'
# Reading Report 'Splunk Inc'
# Reading Report 'Meituan'
# Reading Report 'FormPipe Software'
# Reading Report 'Hyundai Autoever Corp'
# Reading Report 'OneSpan, Inc'
# Reading Report 'China Development Bank Financial Leasing Co'
# Reading Report 'Info Edge India Ltd'
# Reading Report 'International Games System Co Ltd'
# Reading Report 'Infosys Ltd'
# Reading Report 'Salesforce Inc'
# Reading Report 'Newgen Software Technologies Ltd'
# Reading Report 'Renrui Human Resources Technology Holdings Ltd'
# Reading Report 'Comarch'
# Reading Report 'Coursera, Inc'
# Reading Report 'Cadence Design Systems Inc'
# Reading Report 'CGI, Inc'
# Reading Report 'Snap Inc'
# Reading Report 'Pushpay Holdings Ltd'
# Reading Report 'Activision Blizzard, Inc'
# Reading Report 'LINK Mobility Group Holding'
# Reading Report 'Model N Inc'
# Reading Report 'Fortinet Inc'
# Reading Report 'NetDragon Websoft Holdings Ltd'
# Reading Report 'Paylocity Holding Corp'
# Reading Report 'Quest Holdings'
# Reading Report 'Glodon Co'
# Reading Report 'Moneysupermarket Group'
# Reading Report 'Northern Data'
# Reading Report 'Kalera'
# Reading Report 'KE Holdings, Inc'
# Reading Report 'Cars Inc'
# Reading Report 'Coforge Ltd'
# Reading Report 'NNIT'
# Reading Report 'Criteo'
# Reading Report 'Fiverr International Ltd'
# Reading Report 'Booz Allen Hamilton Holding Corp'
# Reading Report 'MTI Ltd'
# Reading Report 'NASDAQ_HCAT_2019'
# Reading Report 'Infotel'
# Reading Report 'NortonLifeLock, Inc'
# Reading Report 'Teradata Corp'
# Reading Report 'Mintra Holding'
# Reading Report 'Samsung SDS Co Ltd'
# Reading Report 'Temenos'
# Reading Report 'Tanla Platforms Ltd'
# Reading Report 'eBay Inc'
# Reading Report 'Cloudera, Inc'
# Reading Report 'Expedia Group Inc'
# Reading Report 'Stillfront Group'
# Reading Report 'NCC Group'
# Reading Report 'Everi Holdings Inc'
# Reading Report 'ChannelAdvisor Corp'
# Reading Report 'Meta Platforms, Inc'
# Reading Report 'FactSet Research Systems Inc'
# Reading Report 'Life360, Inc'
# Reading Report 'Kakaku Inc'
# Reading Report 'GK Software'
# Reading Report 'Focus Home Interactive'
# Reading Report 'BMC Software, Inc'
# Reading Report 'Fujitsu Ltd'
# Reading Report 'Lakala Payment Co Ltd'
# Reading Report 'PTC Inc'
# Reading Report 'Fyber'
# Reading Report 'Conduent'
# Reading Report 'EML Payments Ltd'
# Reading Report 'Spotify Technology'
# Reading Report 'Square Enix Holdings Co Ltd'
# Reading Report 'Schrödinger, Inc'
# Reading Report 'Affirm Holdings, Inc'
# Reading Report 'Sapiens International Corp'
# Reading Report 'Manhattan Associates, Inc'
# Reading Report 'Larsen & Toubro Infotech Limited'
# Reading Report 'Domain Holdings Australia Ltd'
# Reading Report 'EPAM Systems, Inc'
# Reading Report 'Mindtree Ltd'
# Reading Report 'Shopify Inc'
# Reading Report 'Nutanix Inc'
# Reading Report 'Clavister Holding'
# Reading Report 'Solutions 30'
# Reading Report 'Paradox Interactive'
# Reading Report 'Software'
# Reading Report 'Dun & Bradstreet Holdings, Inc'
# Reading Report 'Nets'
# Reading Report 'RingCentral Inc'
# Reading Report 'TravelSky Technology Ltd'
# Reading Report 'Mastercard, Inc'
# Reading Report 'Sinch'
# Reading Report 'Momentive Global, Inc'
# Reading Report 'Ansys Inc'
# Reading Report 'Chanjet Information Technology Co Ltd'
# Reading Report 'Progress Software Corp'
# Reading Report 'Nexi SpA'
# Reading Report 'Marvelous Inc'
# Reading Report 'NEC Networks & System Integration Corp'
# Reading Report 'SB Technology Corp'
# Reading Report 'oRo Co Ltd'
# Reading Report 'Aptitude Software Group'
# Reading Report 'Systena Corp'
# Reading Report 'Pexip Holding'
# Reading Report 'Afterpay Ltd'
# Reading Report 'GPI'
# Reading Report 'dotDigital Group'
# Reading Report 'Qt Group'
# Reading Report 'Nearmap Ltd'
# Reading Report 'Block, Inc'
# Reading Report 'Kps'
# Reading Report 'MEDIA DO Co Ltd'
# Reading Report '24SevenOffice Group'
# Reading Report 'Mobvista, Inc'
# Reading Report 'Megaport Ltd'
# Reading Report 'PagSeguro Digital Ltd'
# Reading Report 'Paychex, Inc'
# Reading Report 'Nomura Research Institute, Ltd'
# Reading Report 'Neptune Co'
# Reading Report 'Scout24'
# Reading Report 'InterDigital Inc'
# Reading Report 'Avaloq Group'
# Reading Report 'The Sage Group'
# Reading Report 'Okta Inc'
# Reading Report 'JoyCity Corp'
# Reading Report 'iDreamSky Technology Holdings Ltd'
# Reading Report 'Kunlun Tech Co Ltd'
# Reading Report 'IVU Traffic Technologies'
# Reading Report 'NHN Corp'

# %%
# Read the key words from our json file
f = open('keywords.json')
keywordBank = json.load(f)
f.close()

# %%
# keywordBank

# %% [markdown]
# ### Extract out features such as:
#
#     - PDF Document Name
#     - Sentence Count (i.e Length of PDF)
#     - ESG Sentences + Percentage of Occurence
#     - Env Sentence + Percentage of Occurence
#     - Social Sentence + Percentage of Occurence
#     - Gov Sentence + Percentage of Occurence
#     - Env Sentiment Score
#     - Social Sentiment Score
#     - Gov Sentiment Score
#     - Averaged ESG Sentiment Score

# %%
# --------------------------- Sentiment Analysis ---------------------------
# This function calculates the sentiment score for the various sentences using VADER
# Sentence:
#   - The sentence to be inputted to the function, which will return the respective sentiment score
#   - If there are > 1 sentence, the average will be computed and returned
def averagedCompoundSentimentScore(sentences):
    sid = SentimentIntensityAnalyzer()
    score = 0
    for sentence in sentences:
        sentiment = sid.polarity_scores(sentence)
        score += sentiment['compound']
    try:
        return score / len(sentences)
    except ZeroDivisionError:
        return score





# --------------------------- Sentence Extraction ---------------------------
# This function extracts out the keywords from the given corpus
# corpus: 
#   - This refers to a document (i.e one company)
# subFeatureKeywords:
#   - A list containing all the keywords which we would like to identify from our sentence bank
def keySentences(corpus, subFeatureKeywords):
    sentencesCaptured = []
    for word in subFeatureKeywords:
        sentencesCaptured.extend([sentence for sentence in corpus if word in sentence])
    return sentencesCaptured





# --------------------------- Print all sentences (Debugging purposes only) ---------------------------
def printAllSentences(corpus, pillar, keywordBank):
    for subFeature, kewords in keywordBank[pillar].items():
        print('\n\n\n')
        print(f"======= Printing Sentences from: '{subFeature}' =======")
        sentences = keySentences(corpus, kewords)
        for sentence in sentences:
            print(sentence)
            print('\n\n')
        




# --------------------------- Subpillar Feature Statistics ---------------------------
# 4 options for pillar: 
#   - 'Environment'
#   - 'Social'
#   - 'Governance'
#   - 'ESG phrases'
# corpus: 
#   - A specific company report, and NOT the whole collection of reports from all companies!
# keywordBank: 
#   - All the keywords from the subpillar
def subPillar_featureStats(corpus, pillar, keywordBank):
    data = {}

    # Calculate the sentences, frequency of sentence occurence, sentiment score etc
    def summaryStatistics(corpus, subFeatureKeywords):
        temp = {
            # "Sentences": None,
            "NumOfSentences": None,
            "FrequencyOfOccurence": None,
            "SentimentScore": None
        }
        # temp['Sentences'] = subpillar_sentences(corpus, keywordBank[pillar])
        sentences = keySentences(corpus, subFeatureKeywords)
        temp['NumOfSentences'] = len(sentences)
        temp['FrequencyOfOccurence'] = round(len(sentences) / len(corpus), 5)
        temp['SentimentScore'] = averagedCompoundSentimentScore(sentences)
        return temp

    for subFeature, subFeatureKeywords in keywordBank[pillar].items():
        data[subFeature] = summaryStatistics(corpus, subFeatureKeywords)
    
    return data





# --------------------------- Complete Feature Statistics ---------------------------
# This combines all the data across the 3 pillars into a dictionary 
# esg_bank:
#   - Complete set of data processed from reading in all the companies
#   - Structure of esg_bank:
#       - Dictionary where
#           - key: company name
#           - value: [sentence1, sentence2, ..., sentenceN]
# companyName:
#   - The company we wish to explore
# keywordBank:
#   - Complete set of data from the keywords.json file
def featureStats(esg_bank, companyName, keywordBank):
    company = {
        companyName: []
    }
    for pillar in [*keywordBank][:-1]:
        temp = {}
        temp[pillar] = subPillar_featureStats(esg_bank[companyName], pillar, keywordBank)
        company[companyName].append(temp)
    return company
    


def processByLength(esg_bank, keywordBank, numberOfReports):
    print('\n\n === Generating feature statistic data from all companies === \n\n')
    companies = []

    def flatten_data(dictionary_data):
        new_data = {
            "Companies": list(dictionary_data.keys())[0],
        }
        for subData in dictionary_data.values():
            for i in range(0, 3):
                for pillar, pillarValues in subData[i].items():
                    for title, data in pillarValues.items():
                        new_data[title + ' Sentiment Score'] = data['SentimentScore'] 
        return new_data

    counter = 0
    for company, data in esg_bank.items():
        if counter == numberOfReports:
            break
        else:
            print(f"Processing data from --- {company}")
            company_data = featureStats(esg_bank, company, keywordBank)
            companies.append(flatten_data(company_data))
            counter += 1

    return pd.DataFrame(companies)

# %%
# --------------------------- Weights for each subpillar ---------------------------
# import from weights.json 
# The weights have been calibrated to sum up to 100%

f = open('weights.json')
weights = json.load(f)
# pprint.pprint(weights)
f.close()

# %%
company_scores = processByLength(esg_corpus, keywordBank, len(esg_corpus))
# Out:
#  === Generating feature statistic data from all companies ===
#
#
# Processing data from --- Enea
# Processing data from --- TIS, Inc
# Processing data from --- Sopra Steria Group
# Processing data from --- Rackspace Technology Global, Inc
# Processing data from --- Infomedia Ltd
# Processing data from --- IGG Inc
# Processing data from --- Datamatics Global Services Ltd
# Processing data from --- Intuit Inc
# Processing data from --- Data Respons
# Processing data from --- POSCO ICT Co Ltd
# Processing data from --- ShotSpotter, Inc
# Processing data from --- Kape Technologies
# Processing data from --- Parsons Corp
# Processing data from --- Crayon Group Holding
# Processing data from --- Grace Technology, Inc
# Processing data from --- G5 Entertainment
# Processing data from --- Happiest Minds Technologies Ltd
# Processing data from --- iFAST Corp Ltd
# Processing data from --- Ceridian HCM Holding, Inc
# Processing data from --- Booking Holdings Inc
# Processing data from --- Nintendo Co Ltd
# Processing data from --- Nihon Unisys, Ltd
# Processing data from --- Autodesk Inc
# Processing data from --- Sykes Enterprises, Inc
# Processing data from --- Naspers Ltd
# Processing data from --- Linx
# Processing data from --- Accenture
# Processing data from --- Linedata Services
# Processing data from --- Lime Technologies
# Processing data from --- Adobe, Inc
# Processing data from --- The Western Union Co
# Processing data from --- TradeDoubler
# Processing data from --- Techedge
# Processing data from --- BlackBerry Ltd
# Processing data from --- Nuance Communications, Inc
# Processing data from --- Cyient Ltd
# Processing data from --- GB Group
# Processing data from --- ManTech International Corp
# Processing data from --- Sabre Corp
# Processing data from --- Information Services International-Dentsu, Ltd
# Processing data from --- BrainChip Holdings Ltd
# Processing data from --- Rovio Entertainment Oyj
# Processing data from --- Computershare
# Processing data from --- Blackbaud, Inc
# Processing data from --- FLEETCOR Technologies, Inc
# Processing data from --- Mitsubishi Research Institute, Inc
# Processing data from --- Joy Spreader Group, Inc
# Processing data from --- Money Forward, Inc
# Processing data from --- Just Dial Ltd
# Processing data from --- Matrix IT Ltd
# Processing data from --- Sea Ltd
# Processing data from --- Alpha Systems Inc
# Processing data from --- Cass Information Systems, Inc
# Processing data from --- Fidelity National Information Services Inc
# Processing data from --- Redbubble Ltd
# Processing data from --- Carsales
# Processing data from --- Aspire Global
# Processing data from --- Net One Systems Co Ltd
# Processing data from --- Evertec Inc
# Processing data from --- TietoEVRY Corp
# Processing data from --- HubSpot Inc
# Processing data from --- Tenable Holdings, Inc
# Processing data from --- Mensch und Maschine Software
# Processing data from --- Paycom Software Inc
# Processing data from --- Jack Henry & Associates Inc
# Processing data from --- DXC Technology
# Processing data from --- Technology One Ltd
# Processing data from --- CMGE Technology Group Ltd
# Processing data from --- BTRS Holdings, Inc
# Processing data from --- Microsoft Corp
# Processing data from --- Mastek Ltd
# Processing data from --- Proact IT Group
# Processing data from --- SS&C Technologies Holdings, Inc
# Processing data from --- Lyft, Inc
# Processing data from --- Tech Mahindra Ltd
# Processing data from --- Alight, Inc
# Processing data from --- GoDaddy Inc
# Processing data from --- BlackLine, Inc
# Processing data from --- Scicom (MSC) Bhd
# Processing data from --- SAP
# Processing data from --- Hi Sun Technology (China) Ltd
# Processing data from --- Atea
# Processing data from --- SCSK Corp
# Processing data from --- Sesa SpA
# Processing data from --- Cision Ltd
# Processing data from --- Indra Sistemas
# Processing data from --- Science Applications International Corp
# Processing data from --- Esker
# Processing data from --- FD Technologies
# Processing data from --- CSAM Health Group
# Processing data from --- NTT DATA Corp
# Processing data from --- Keywords Studios
# Processing data from --- F-Secure
# Processing data from --- Integrated Research Ltd
# Processing data from --- Leidos Holdings Inc
# Processing data from --- SDL
# Processing data from --- Black Knight, Inc
# Processing data from --- Nepa
# Processing data from --- BIMobject
# Processing data from --- Atos
# Processing data from --- HCL Technologies Ltd
# Processing data from --- Q2 Holdings, Inc
# Processing data from --- Sword Group
# Processing data from --- NICE Ltd (Israel)
# Processing data from --- PayPal Holdings Inc
# Processing data from --- Audinate Group Ltd
# Processing data from --- Mercadolibre, Inc
# Processing data from --- Bytes Technology Group
# Processing data from --- New Work
# Processing data from --- CommVault Systems
# Processing data from --- PROS Holdings, Inc
# Processing data from --- msg life ag
# Processing data from --- Kanematsu Electronics Ltd
# Processing data from --- Kinaxis Inc
# Processing data from --- Birlasoft Ltd
# Processing data from --- Globant
# Processing data from --- SimCorp
# Processing data from --- Bilibili, Inc
# Processing data from --- Readly International
# Processing data from --- Cielo
# Processing data from --- Quotient Technology Inc
# Processing data from --- Razer, Inc
# Processing data from --- Datagroup
# Processing data from --- Ideanomics, Inc
# Processing data from --- Sumo Logic, Inc
# Processing data from --- Etsy Inc
# Processing data from --- AVEVA Group
# Processing data from --- SII
# Processing data from --- Hinduja Global Solutions Ltd
# Processing data from --- NCsoft Corp
# Processing data from --- Better Collective
# Processing data from --- Match Group, Inc
# Processing data from --- Dropbox, Inc
# Processing data from --- Nemetschek
# Processing data from --- Mango Excellent Media Co Ltd
# Processing data from --- Tencent Holdings Ltd
# Processing data from --- Adyen
# Processing data from --- Rightmove
# Processing data from --- L&T Technology Services Ltd
# Processing data from --- NetScout Systems, Inc
# Processing data from --- Bravura Solutions Ltd
# Processing data from --- Mphasis Ltd
# Processing data from --- Devoteam
# Processing data from --- GFT Technologies
# Processing data from --- Bouvet
# Processing data from --- Ideagen
# Processing data from --- Digimarc Corp
# Processing data from --- TeamViewer
# Processing data from --- Total System Services
# Processing data from --- cBrain
# Processing data from --- Computacenter
# Processing data from --- Kahoot!
# Processing data from --- Mimecast Ltd
# Processing data from --- ExlService Holdings, Inc
# Processing data from --- Embracer Group
# Processing data from --- mixi Inc
# Processing data from --- Iflytek Co Ltd
# Processing data from --- Softronic
# Processing data from --- DKV MOBILITY SERVICES HOLDING
# Processing data from --- Flexential Corp
# Processing data from --- Link Administration Holdings Ltd
# Processing data from --- Qualys Inc
# Processing data from --- Itera
# Processing data from --- Blue Prism Group PLC
# Processing data from --- NetEnt
# Processing data from --- Penneo
# Processing data from --- Electronic Arts Inc
# Processing data from --- SoftwareONE Holding
# Processing data from --- Chatwork Co
# Processing data from --- Rakus Co Ltd
# Processing data from --- Prosus NV
# Processing data from --- Remedy Entertainment
# Processing data from --- F5, Inc
# Processing data from --- Fiserv Inc
# Processing data from --- International Business Machines Corp
# Processing data from --- Leo Group Co Ltd
# Processing data from --- Kakao Games Corp
# Processing data from --- Optim Corp
# Processing data from --- Just Eat Takeaway
# Processing data from --- Endava
# Processing data from --- Polygon
# Processing data from --- Ordina NV
# Processing data from --- FDM Group Holdings
# Processing data from --- Palo Alto Networks Inc
# Processing data from --- Synopsys, Inc
# Processing data from --- SMS Co Ltd
# Processing data from --- MyEG Services Bhd
# Processing data from --- Cognizant Technology Solutions Corp
# Processing data from --- Cloudflare, Inc
# Processing data from --- Avast
# Processing data from --- ITOCHU Techno-Solutions Corp
# Processing data from --- Imdex Ltd
# Processing data from --- Softcat
# Processing data from --- Persistent Systems Ltd
# Processing data from --- IRESS Ltd
# Processing data from --- Delivery Hero
# Processing data from --- FriendTimes, Inc
# Processing data from --- Gofore
# Processing data from --- NetEase, Inc
# Processing data from --- Citrix Systems Inc
# Processing data from --- Genpact Ltd
# Processing data from --- Equiniti Group
# Processing data from --- Totvs
# Processing data from --- GMO Payment Gateway Inc
# Processing data from --- IAC Interactive Corp
# Processing data from --- Econocom Group
# Processing data from --- Learning Technologies Group
# Processing data from --- Esi Group
# Processing data from --- Kingdee International Software Group Co Ltd
# Processing data from --- Renalytix
# Processing data from --- Starbreeze
# Processing data from --- Logicom Public Ltd
# Processing data from --- Network International Holdings
# Processing data from --- Iomart Group
# Processing data from --- Catena Media
# Processing data from --- Silverlake Axis Ltd
# Processing data from --- Take-Two Interactive Software, Inc
# Processing data from --- ACI Worldwide, Inc
# Processing data from --- Maoyan Entertainment
# Processing data from --- Rakuten Group, Inc
# Processing data from --- Forrester Research, Inc
# Processing data from --- CoreLogic Inc
# Processing data from --- NAVER Corp
# Processing data from --- Izertis
# Processing data from --- Bmit Technologies
# Processing data from --- Nagarro
# Processing data from --- Dassault Systems
# Processing data from --- Modern Times Group MTG
# Processing data from --- Kainos Group
# Processing data from --- CWT International Ltd
# Processing data from --- EHang Holdings Ltd
# Processing data from --- Frontier Developments
# Processing data from --- Reply SPA
# Processing data from --- Absolute Software Corp
# Processing data from --- Bittium Oyj
# Processing data from --- ServiceNow Inc
# Processing data from --- KPIT Technologies Ltd
# Processing data from --- PSI Software AG
# Processing data from --- China TransInfo Technology Co
# Processing data from --- IndiaMART InterMESH Ltd
# Processing data from --- Netcompany Group
# Processing data from --- Digia
# Processing data from --- Data#3 Ltd
# Processing data from --- Mercari, Inc
# Processing data from --- OTSUKA CORP
# Processing data from --- Inke Ltd
# Processing data from --- Media & Games Invest
# Processing data from --- Costar Group, Inc
# Processing data from --- HengTen Networks Group Ltd
# Processing data from --- Global Dominion Access
# Processing data from --- Akamai Technologies Inc
# Processing data from --- adesso
# Processing data from --- Sunevision Holdings Ltd
# Processing data from --- Tata Consultancy Services Ltd
# Processing data from --- Gaming Innovation Group Inc
# Processing data from --- Fair Isaac Corp
# Processing data from --- Exasol
# Processing data from --- Sansan, Inc
# Processing data from --- Nuix Ltd
# Processing data from --- DTS Corp
# Processing data from --- IAR Systems Group
# Processing data from --- CyberArk Software Ltd
# Processing data from --- ICT Group
# Processing data from --- home24
# Processing data from --- Origo hf
# Processing data from --- Kuaishou Technology
# Processing data from --- Liquidity Services, Inc
# Processing data from --- Thunder Software Technology Co Ltd
# Processing data from --- Global Payments Inc
# Processing data from --- Edenred
# Processing data from --- Open Text Corp
# Processing data from --- Micro Focus International
# Processing data from --- 2U, Inc
# Processing data from --- Kingsoft Corp Ltd
# Processing data from --- Mercell Holding
# Processing data from --- Roper Technologies Inc
# Processing data from --- Procore Technologies, Inc
# Processing data from --- Coupa Software, Inc
# Processing data from --- Oracle Corp
# Processing data from --- Fabasoft
# Processing data from --- Medallia, Inc
# Processing data from --- Atlassian Corp
# Processing data from --- Alibaba Group Holding Ltd
# Processing data from --- Splunk Inc
# Processing data from --- Meituan
# Processing data from --- FormPipe Software
# Processing data from --- Hyundai Autoever Corp
# Processing data from --- OneSpan, Inc
# Processing data from --- China Development Bank Financial Leasing Co
# Processing data from --- Info Edge India Ltd
# Processing data from --- International Games System Co Ltd
# Processing data from --- Infosys Ltd
# Processing data from --- Salesforce Inc
# Processing data from --- Newgen Software Technologies Ltd
# Processing data from --- Renrui Human Resources Technology Holdings Ltd
# Processing data from --- Comarch
# Processing data from --- Coursera, Inc
# Processing data from --- Cadence Design Systems Inc
# Processing data from --- CGI, Inc
# Processing data from --- Snap Inc
# Processing data from --- Pushpay Holdings Ltd
# Processing data from --- Activision Blizzard, Inc
# Processing data from --- LINK Mobility Group Holding
# Processing data from --- Model N Inc
# Processing data from --- Fortinet Inc
# Processing data from --- NetDragon Websoft Holdings Ltd
# Processing data from --- Paylocity Holding Corp
# Processing data from --- Quest Holdings
# Processing data from --- Glodon Co
# Processing data from --- Moneysupermarket Group
# Processing data from --- Northern Data
# Processing data from --- Kalera
# Processing data from --- KE Holdings, Inc
# Processing data from --- Cars Inc
# Processing data from --- Coforge Ltd
# Processing data from --- NNIT
# Processing data from --- Criteo
# Processing data from --- Fiverr International Ltd
# Processing data from --- Booz Allen Hamilton Holding Corp
# Processing data from --- MTI Ltd
# Processing data from --- NASDAQ_HCAT_2019
# Processing data from --- Infotel
# Processing data from --- NortonLifeLock, Inc
# Processing data from --- Teradata Corp
# Processing data from --- Mintra Holding
# Processing data from --- Samsung SDS Co Ltd
# Processing data from --- Temenos
# Processing data from --- Tanla Platforms Ltd
# Processing data from --- eBay Inc
# Processing data from --- Cloudera, Inc
# Processing data from --- Expedia Group Inc
# Processing data from --- Stillfront Group
# Processing data from --- NCC Group
# Processing data from --- Everi Holdings Inc
# Processing data from --- ChannelAdvisor Corp
# Processing data from --- Meta Platforms, Inc
# Processing data from --- FactSet Research Systems Inc
# Processing data from --- Life360, Inc
# Processing data from --- Kakaku Inc
# Processing data from --- GK Software
# Processing data from --- Focus Home Interactive
# Processing data from --- BMC Software, Inc
# Processing data from --- Fujitsu Ltd
# Processing data from --- Lakala Payment Co Ltd
# Processing data from --- PTC Inc
# Processing data from --- Fyber
# Processing data from --- Conduent
# Processing data from --- EML Payments Ltd
# Processing data from --- Spotify Technology
# Processing data from --- Square Enix Holdings Co Ltd
# Processing data from --- Schrödinger, Inc
# Processing data from --- Affirm Holdings, Inc
# Processing data from --- Sapiens International Corp
# Processing data from --- Manhattan Associates, Inc
# Processing data from --- Larsen & Toubro Infotech Limited
# Processing data from --- Domain Holdings Australia Ltd
# Processing data from --- EPAM Systems, Inc
# Processing data from --- Mindtree Ltd
# Processing data from --- Shopify Inc
# Processing data from --- Nutanix Inc
# Processing data from --- Clavister Holding
# Processing data from --- Solutions 30
# Processing data from --- Paradox Interactive
# Processing data from --- Software
# Processing data from --- Dun & Bradstreet Holdings, Inc
# Processing data from --- Nets
# Processing data from --- RingCentral Inc
# Processing data from --- TravelSky Technology Ltd
# Processing data from --- Mastercard, Inc
# Processing data from --- Sinch
# Processing data from --- Momentive Global, Inc
# Processing data from --- Ansys Inc
# Processing data from --- Chanjet Information Technology Co Ltd
# Processing data from --- Progress Software Corp
# Processing data from --- Nexi SpA
# Processing data from --- Marvelous Inc
# Processing data from --- NEC Networks & System Integration Corp
# Processing data from --- SB Technology Corp
# Processing data from --- oRo Co Ltd
# Processing data from --- Aptitude Software Group
# Processing data from --- Systena Corp
# Processing data from --- Pexip Holding
# Processing data from --- Afterpay Ltd
# Processing data from --- GPI
# Processing data from --- dotDigital Group
# Processing data from --- Qt Group
# Processing data from --- Nearmap Ltd
# Processing data from --- Block, Inc
# Processing data from --- Kps
# Processing data from --- MEDIA DO Co Ltd
# Processing data from --- 24SevenOffice Group
# Processing data from --- Mobvista, Inc
# Processing data from --- Megaport Ltd
# Processing data from --- PagSeguro Digital Ltd
# Processing data from --- Paychex, Inc
# Processing data from --- Nomura Research Institute, Ltd
# Processing data from --- Neptune Co
# Processing data from --- Scout24
# Processing data from --- InterDigital Inc
# Processing data from --- Avaloq Group
# Processing data from --- The Sage Group
# Processing data from --- Okta Inc
# Processing data from --- JoyCity Corp
# Processing data from --- iDreamSky Technology Holdings Ltd
# Processing data from --- Kunlun Tech Co Ltd
# Processing data from --- IVU Traffic Technologies
# Processing data from --- NHN Corp

# %%
company_scores
# Out:
#                              Companies  \
# 0                                 Enea
# 1                             TIS, Inc
# 2                   Sopra Steria Group
# 3     Rackspace Technology Global, Inc
# 4                        Infomedia Ltd
# ..                                 ...
# 402                       JoyCity Corp
# 403  iDreamSky Technology Holdings Ltd
# 404                 Kunlun Tech Co Ltd
# 405           IVU Traffic Technologies
# 406                           NHN Corp
#
#      Opportunities in Clean Tech Sentiment Score  \
# 0                                       0.425327
# 1                                       0.521842
# 2                                       0.504519
# 3                                       0.544586
# 4                                       0.341683
# ..                                           ...
# 402                                     0.732820
# 403                                     0.256462
# 404                                     0.680855
# 405                                     0.439241
# 406                                     0.555762
#
#      Carbon Emissions Sentiment Score  Water Stress Sentiment Score  \
# 0                            0.557400                      0.072240
# 1                            0.432322                      0.996200
# 2                            0.281237                      0.347221
# 3                            0.101990                      0.229163
# 4                           -0.401900                      0.000000
# ..                                ...                           ...
# 402                          0.315017                      0.149886
# 403                          0.303830                      0.339791
# 404                          0.527367                      0.301933
# 405                          0.246389                      0.000000
# 406                          0.347949                     -0.037378
#
#      Electronic Waste Sentiment Score  \
# 0                            0.234367
# 1                            0.239570
# 2                            0.022540
# 3                            0.006082
# 4                            0.547075
# ..                                ...
# 402                          0.049583
# 403                          0.267332
# 404                          0.066330
# 405                          0.009519
# 406                         -0.193885
#
#      Toxic Emissions & Waste Sentiment Score  \
# 0                                   0.000000
# 1                                   0.000000
# 2                                   0.144443
# 3                                   0.542300
# 4                                   0.000000
# ..                                       ...
# 402                                -0.350000
# 403                                -0.207264
# 404                                -0.005139
# 405                                 0.000000
# 406                                 0.000000
#
#      Human Capital Development Sentiment Score  \
# 0                                     0.375837
# 1                                     0.535148
# 2                                     0.452177
# 3                                     0.213250
# 4                                     0.483650
# ..                                         ...
# 402                                   0.049314
# 403                                   0.467616
# 404                                   0.659550
# 405                                   0.323867
# 406                                   0.578182
#
#      Privacy and Data Security Sentiment Score  \
# 0                                     0.355967
# 1                                     0.416305
# 2                                     0.392583
# 3                                     0.465908
# 4                                     0.396403
# ..                                         ...
# 402                                   0.640739
# 403                                   0.349031
# 404                                   0.494459
# 405                                   0.302686
# 406                                   0.459825
#
#      Labor Management Sentiment Score  Governance Sentiment Score
# 0                            0.327428                    0.284460
# 1                            0.501125                    0.564920
# 2                            0.459815                    0.456827
# 3                            0.532997                    0.347849
# 4                            0.375560                    0.378634
# ..                                ...                         ...
# 402                          0.688136                    0.609192
# 403                          0.337683                    0.374027
# 404                          0.542107                    0.405922
# 405                          0.244283                    0.162826
# 406                          0.555532                    0.470001
#
# [407 rows x 10 columns]

# %%
# pprint.pprint(featureStats(esg_corpus, 'Enea', keywordBank))

# %%
# Merging Target values to the dataframe
corporate = pd.read_csv('Corporate2.0.csv')

# Filter out those that contains the report
corporate_new = corporate.loc[corporate['Annual Report'].notnull()].reset_index(drop=True)

# Select relevant columns
corporate_new = corporate_new[['Companies', 'ESG Risk Score', 'ESG Risk Rating']]

len(corporate_new)
# Out:
# 417

# %%
# Merge with dataframe from above
corporate_new_merged = pd.merge(corporate_new, company_scores, how='inner', on = 'Companies').reset_index(drop=True)
corporate_new_merged
# Out:
#                     Companies  ESG Risk Score      ESG Risk Rating  \
# 0         24SevenOffice Group            24.6      Medium ESG Risk
# 1                     2U, Inc            19.8         Low ESG Risk
# 2      Absolute Software Corp            24.1      Medium ESG Risk
# 3                   Accenture             9.7  Negligible ESG Risk
# 4          ACI Worldwide, Inc            20.8      Medium ESG Risk
# ..                        ...             ...                  ...
# 402                  TIS, Inc            19.3         Low ESG Risk
# 403     Total System Services            18.0         Low ESG Risk
# 404                     Totvs            19.9         Low ESG Risk
# 405              TradeDoubler            32.8        High ESG Risk
# 406  TravelSky Technology Ltd            22.3      Medium ESG Risk
#
#      Opportunities in Clean Tech Sentiment Score  \
# 0                                       0.357958
# 1                                       0.226180
# 2                                      -0.279050
# 3                                       0.632968
# 4                                       0.399900
# ..                                           ...
# 402                                     0.521842
# 403                                     0.607006
# 404                                     0.537422
# 405                                     0.316283
# 406                                     0.646998
#
#      Carbon Emissions Sentiment Score  Water Stress Sentiment Score  \
# 0                            0.000000                      0.000000
# 1                           -0.077200                     -0.077200
# 2                           -0.229400                     -0.421500
# 3                            0.453108                     -0.421500
# 4                            0.353917                      0.470240
# ..                                ...                           ...
# 402                          0.432322                      0.996200
# 403                          0.389800                      0.306450
# 404                          0.156250                      0.234375
# 405                          0.000000                      0.000000
# 406                          0.465929                      0.329006
#
#      Electronic Waste Sentiment Score  \
# 0                            0.000000
# 1                           -0.077200
# 2                           -0.421500
# 3                            0.744725
# 4                            0.177225
# ..                                ...
# 402                          0.239570
# 403                         -0.100911
# 404                         -0.178937
# 405                          0.209533
# 406                          0.081315
#
#      Toxic Emissions & Waste Sentiment Score  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ..                                       ...
# 402                                  0.00000
# 403                                  0.00000
# 404                                  0.00000
# 405                                  0.00000
# 406                                 -0.46016
#
#      Human Capital Development Sentiment Score  \
# 0                                     0.471713
# 1                                     0.563257
# 2                                     0.000000
# 3                                     0.610265
# 4                                     0.678200
# ..                                         ...
# 402                                   0.535148
# 403                                   0.000000
# 404                                   0.510184
# 405                                   0.348928
# 406                                   0.614006
#
#      Privacy and Data Security Sentiment Score  \
# 0                                     0.375589
# 1                                     0.406256
# 2                                     0.231411
# 3                                     0.381267
# 4                                     0.290737
# ..                                         ...
# 402                                   0.416305
# 403                                   0.380440
# 404                                   0.503567
# 405                                   0.340593
# 406                                   0.532757
#
#      Labor Management Sentiment Score  Governance Sentiment Score
# 0                            0.218405                    0.330786
# 1                            0.275578                    0.390339
# 2                            0.827100                    0.488943
# 3                            0.518605                    0.600880
# 4                            0.232244                    0.263880
# ..                                ...                         ...
# 402                          0.501125                    0.564920
# 403                          0.232475                    0.535517
# 404                          0.447113                    0.468587
# 405                          0.274121                    0.243602
# 406                          0.610578                    0.578349
#
# [407 rows x 12 columns]

# %%
# Check which columns do not match
coy_sorted = company_scores.sort_values(['Companies'])
coy_sorted = coy_sorted[['Companies']].reset_index(drop=True)

corporate_new_sorted = corporate_new.sort_values(['Companies'])
corporate_new_sorted = corporate_new_sorted[['Companies']].reset_index(drop=True)

count = 0
for company in list(coy_sorted['Companies']):
    if company not in list(corporate_new_sorted['Companies']):
        print(f"Company not found: {company}")
        count += 1
print(f"{count} discrepancies found!")
# Out:
# Company not found: Cars Inc
# Company not found: NASDAQ_HCAT_2019
# Company not found: Procore Technologies, Inc
# Company not found: Schrödinger, Inc
# 4 discrepancies found!

# %%
# Output data to csv file
corporate_new_merged.to_csv('data.csv')

# %%
# pprint.pprint(featureStats(esg_corpus, 'NTT DATA Corp', keywordBank))

# %%
# subPillar_featureStats(esg_corpus['IAC_InteractiveCorp 2020'], 'Environment', keywordBank)

# %%
# subPillar_featureStats(esg_corpus['IAC_InteractiveCorp 2020'], 'Social', keywordBank)

# %%
# df = featureStatistic(esg_corpus, esg_keywords, environment_features, social_features, governance_features)
# df
